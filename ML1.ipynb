# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#I first downloaded housing csv file from OpenMl
df=pd.read_csv('housing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#It gives the information of every blocks
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
#It gives the statistics info of my csv file.
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist(bins=40,figsize=(11,7))#bins ar the barnumbers
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df#this is the original excel
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Now I wanna make train and test file which for instance test concludes 20 per cent(test_ratio) of data and train 80 percent, so first I should permute the rows indices randomly then, choose the random values
def shuffle_and_split_df(df, test_ratio):
  random_indices=np.random.permutation(len(df))
  test_set_size=int(len(df)*test_ratio) 
  test_random_indices=random_indices[:test_set_size]
  train_random_indices=random_indices[test_set_size:]
  #this code converts indices into values in pandas!
  return df.iloc[test_random_indices] , df.iloc[train_random_indices]

# %%
train_set, test_set= shuffle_and_split_df(df,0.2) #test_ratio in my example is 0.2.
#Finally, youshould notice this process is not efficient and we have some alternative technics bc this process is random and every
#time you run the code, you have new train and test data. Moreover; if you add data in future, your permutation will be ruined!

# %%
#by adding   np.random.seed(40) data saves and won't change in any run, but if we add or remove data we will have problem.
def shuffle_and_split_df(df, test_ratio):
  np.random.seed(40)
  random_indices=np.random.permutation(len(df))
  test_set_size=int(len(df)*test_ratio) 
  test_random_indices=random_indices[:test_set_size]
  train_random_indices=random_indices[test_set_size:]
  #this code converts indices into values in pandas!
  return df.iloc[test_random_indices] , df.iloc[train_random_indices]
shuffle_and_split_df(df,0.2)[0]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6607     -118.14     34.18                47.0       3457.0           622.0
# 884      -121.97     37.54                31.0       1949.0           344.0
# 9457     -123.84     39.83                19.0       1461.0           340.0
# 18681    -121.82     36.86                17.0       1573.0           272.0
# 4654     -118.33     34.05                48.0       2405.0           527.0
# ...          ...       ...                 ...          ...             ...
# 19314    -122.87     38.43                36.0       1987.0           387.0
# 15433    -117.25     33.20                10.0       2050.0           473.0
# 3631     -118.43     34.23                35.0       2049.0           390.0
# 3689     -118.36     34.23                15.0       2485.0           742.0
# 11895    -117.36     33.97                32.0       1625.0           335.0
#
# ...

# %%
#If we update data, we need a process which my deviation doesn't change. we need identifier. 
from zlib import crc32
#The line  code crc32(np.array([1,2])) identifies the data. it returns a 32 byte number.

#for checking identifier:
def is_identifier_in_test_set(identifier,test_ratio):
    return crc32(np.int64(identifier)) < test_ratio*2**32      #it checks if first 20% is in test. 
def split_train_test_with_identifier_hash(df, test_ratio, identifier_column):
    identifiers=df[identifier_column]
    in_test_set=identifiers.apply(lambda id_ : is_identifier_in_test_set(id_, test_ratio))
    return df.loc[~in_test_set] , df.loc[in_test_set]

# %%
train_set, test_set= split_train_test_with_identifier_hash(df.reset_index(), 0.2, "index")
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0          0    -122.23     37.88                41.0        880.0
# 1          1    -122.22     37.86                21.0       7099.0
# 3          3    -122.25     37.85                52.0       1274.0
# 4          4    -122.25     37.85                52.0       1627.0
# 6          6    -122.25     37.84                52.0       2535.0
# ...      ...        ...       ...                 ...          ...
# 20635  20635    -121.09     39.48                25.0       1665.0
# 20636  20636    -121.21     39.49                18.0        697.0
# 20637  20637    -121.22     39.43                17.0       2254.0
# 20638  20638    -121.32     39.43                18.0       1860.0
# 20639  20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# ...

# %%
test_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 2          2    -122.24     37.85                52.0       1467.0
# 5          5    -122.25     37.85                52.0        919.0
# 12        12    -122.26     37.85                52.0       2491.0
# 16        16    -122.27     37.85                52.0       1966.0
# 23        23    -122.27     37.84                52.0       1688.0
# ...      ...        ...       ...                 ...          ...
# 20615  20615    -121.54     39.08                23.0       1076.0
# 20617  20617    -121.53     39.06                20.0        561.0
# 20622  20622    -121.44     39.00                20.0        755.0
# 20626  20626    -121.43     39.18                36.0       1124.0
# 20629  20629    -121.39     39.12                28.0      10035.0
#
#        total_bedrooms  population  households  median_income  \
# 2               190.0       496.0       177.0         7.2574
# ...

# %%
#If you remove a row, your data will be ruined bc you are working with index. you can choose another column as an identifier:
df_with_identifier=df
df_with_identifier["identifier"]=df ["longitude"]*1000+ df["latitude"]
df_with_identifier #Now we have a new column as identifier
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
train_set, test_set= split_train_test_with_identifier_hash(df_with_identifier, 0.2, "identifier")
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Finally, this process was the best and ultimate, However we can work with scikit library from scikit-learn.org websit and search any
#function we need forexample I searched train_test_split
#First I installed scikit by pip install -U scikit-learn
from sklearn.model_selection import train_test_split
train_set,test_set= train_test_split(df, test_size=0.2, random_state=40)#random_state works similar to seed.
#This work like the first process we did, so becareful you musn't change data!

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9226     -120.04     36.93                11.0       3606.0           699.0
# 11826    -121.04     39.00                21.0       4059.0           730.0
# 4553     -118.24     34.06                33.0        390.0           199.0
# 10787    -117.92     33.64                25.0       2224.0           580.0
# 4104     -118.35     34.13                39.0       1610.0           278.0
# ...          ...       ...                 ...          ...             ...
# 11532    -118.09     33.77                26.0       5359.0          1508.0
# 16065    -122.48     37.75                49.0       2203.0           407.0
# 14501    -117.23     32.86                16.0       1200.0           468.0
# 14555    -117.13     32.96                15.0       2267.0           292.0
# 11590    -118.01     33.78                26.0       2343.0           377.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6607     -118.14     34.18                47.0       3457.0           622.0
# 884      -121.97     37.54                31.0       1949.0           344.0
# 9457     -123.84     39.83                19.0       1461.0           340.0
# 18681    -121.82     36.86                17.0       1573.0           272.0
# 4654     -118.33     34.05                48.0       2405.0           527.0
# ...          ...       ...                 ...          ...             ...
# 19314    -122.87     38.43                36.0       1987.0           387.0
# 15433    -117.25     33.20                10.0       2050.0           473.0
# 3631     -118.43     34.23                35.0       2049.0           390.0
# 3689     -118.36     34.23                15.0       2485.0           742.0
# 11895    -117.36     33.97                32.0       1625.0           335.0
#
# ...

# %%
#Stratified sampling:The percentage of your important feature should be the same in train an test set.
#First categorize continious data column(your important feature)
df["median_income_categorised"]=pd.cut(df["median_income"],bins=[0.0,1.5,3.0,4.5,6.0,np.inf],labels=[1,2,3,4,5])

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df["median_income_categorised"].value_counts().sort_index().plot.bar(grid=True)
# Out:
# <Axes: xlabel='median_income_categorised'>

# %%
#operating stratified sampling:
from sklearn.model_selection import StratifiedShuffleSplit
sss=StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=40)
stratified_split= []
for train_i ,test_i in sss.split (df,df["median_income_categorised"]):
    stratified_train_set_n=df.iloc[train_i]
    stratified_test_set_n=df.iloc[test_i]
    stratified_split.append([stratified_train_set_n, stratified_test_set_n])
stratified_split
# Out:
# [[       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#   16415    -121.26     37.88                42.0        465.0            93.0
#   1279     -121.64     37.85                22.0       1999.0           415.0
#   7741     -118.15     33.95                35.0       2753.0           702.0
#   4425     -118.24     34.07                27.0        223.0            80.0
#   1283     -121.82     38.02                46.0        176.0            43.0
#   ...          ...       ...                 ...          ...             ...
#   1221     -120.65     38.28                21.0       3095.0           681.0
#   12640    -121.45     38.53                34.0       1893.0           415.0
#   5747     -118.27     34.17                48.0       1560.0           280.0
#   16224    -121.33     37.98                36.0       3113.0           576.0
#   8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
stratified_train_set,stratified_test_set = stratified_split[0]

# %%
stratified_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
stratified_train_set["median_income_categorised"].value_counts()/len(stratified_train_set)
# Out:
# median_income_categorised
# 3    0.350594
# 2    0.318859
# 4    0.176296
# 5    0.114462
# 1    0.039789
# Name: count, dtype: float64

# %%
stratified_test_set["median_income_categorised"].value_counts()/len(stratified_test_set)#You can see the proportional of both
#train and test set is the same.
# Out:
# median_income_categorised
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
#you could stratify with this ready function too.
str_train_set,str_test_set= train_test_split(df, test_size=0.2,stratify=df["median_income_categorised"], random_state=40)

# %%
str_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
str_train_set["median_income_categorised"].value_counts()/len(stratified_train_set)
# Out:
# median_income_categorised
# 3    0.350594
# 2    0.318859
# 4    0.176296
# 5    0.114462
# 1    0.039789
# Name: count, dtype: float64

# %%
str_test_set["median_income_categorised"].value_counts()/len(stratified_test_set)
# Out:
# median_income_categorised
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
#Finally, you can remove your median income categorised column.
df = df.drop("median_income_categorised",axis=1)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
str_train_set
str_train_set=str_train_set.drop("median_income_categorised",axis=1)
str_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16344 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   median_house_value  16512 non-null  float64
#  9   ocean_proximity     16512 non-null  object
#  10  identifier          16512 non-null  float64
#  11  rooms_per_house     16512 non-null  float64
#  12  bedrooms_ratio      16344 non-null  float64
#  13  people_per_house    16512 non-null  float64
# dtypes: float64(13), object(1)
# memory usage: 1.9+ MB

# %%
#Visualize:
train=str_train_set

# %%
sns.scatterplot(data=train, x="longitude",y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
#Now I wanna adjust the color of circles with population
ax=sns.scatterplot(data=train, x="longitude",y="latitude",size="population", alpha=0.2,hue="median_house_value" )#alpha shows the density of population.
#hue shows another feature in range of colors.size shows population in range of circle size. 
sns.move_legend(ax,"upper left", bbox_to_anchor=(1,1))#the box of median_house_value and population was so big, so I moved it in upper left.

# %%
#Correlation
train.corr(numeric_only=True)["median_house_value"]#Notice the highest correlation coefficient i=of median house value is for median income
#and this is the reason why I choices it as categorise(in stratification)!!!
#Becarefu! If we have correlation in 2 features, it doesnt mean we have causality! Causality is not that simple.
# Out:
# longitude            -0.051167
# latitude             -0.137691
# housing_median_age    0.105329
# total_rooms           0.138007
# total_bedrooms        0.052814
# population           -0.021544
# households            0.070014
# median_income         0.686865
# median_house_value    1.000000
# identifier           -0.051364
# rooms_per_house       0.159500
# bedrooms_ratio       -0.255178
# people_per_house     -0.027110
# Name: median_house_value, dtype: float64

# %%
sns.scatterplot(data=train, x="median_income",y="median_house_value",alpha=0.2)#Now you can notice the correlation line.
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
#ATTRIBUTE COMBINATION
#Forexample now we wanna know how many rooms does any houshold have.
train["rooms_per_house"]=train["total_rooms"]/train["households"]
train["bedrooms_ratio"]=train["total_bedrooms"]/train["total_rooms"]
train["people_per_house"]=train["population"]/train["households"]

# %%
train.corr(numeric_only=True)["median_house_value"]
# Out:
# longitude            -0.051167
# latitude             -0.137691
# housing_median_age    0.105329
# total_rooms           0.138007
# total_bedrooms        0.052814
# population           -0.021544
# households            0.070014
# median_income         0.686865
# median_house_value    1.000000
# identifier           -0.051364
# rooms_per_house       0.159500
# bedrooms_ratio       -0.255178
# people_per_house     -0.027110
# Name: median_house_value, dtype: float64

# %%
#Prepare Data:
train_features=train.drop("median_house_value", axis=1)
train_target=train["median_house_value"]
train_target
# Out:
# 16415    158300.0
# 1279     253900.0
# 7741     209000.0
# 4425     137500.0
# 1283      93800.0
#            ...
# 1221     104000.0
# 12640     75400.0
# 5747     354700.0
# 16224     84600.0
# 8967     336000.0
# Name: median_house_value, Length: 16512, dtype: float64

# %%
##Data Cleanin:
#missing values are empty values.
train_features.info()
#You can notice total_bedrooms and bedrooms_ratio have different numbers.so total_bedrooms have null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16344 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   ocean_proximity     16512 non-null  object
#  9   identifier          16512 non-null  float64
#  10  rooms_per_house     16512 non-null  float64
#  11  bedrooms_ratio      16344 non-null  float64
#  12  people_per_house    16512 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.8+ MB

# %%
#we can ommit null rows, then all the volumns will have 15344 Non-Null. Here bc we have large data, that's okay to ommit nonvalues
#but in tiny data, it is not efficient. An other way is to omit different columns!but our column(total bedrooms) had hogh correlation 
#so we wont omit the column!
#The best way, is to put average number of other data instead of null values.

# %%
#Doing the first solution:(ommiting rows)
train_features.dropna(subset=["total_bedrooms"])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
#remove columns:
train_features.drop("total_bedrooms",axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 16415    -121.26     37.88                42.0        465.0       256.0
# 1279     -121.64     37.85                22.0       1999.0       967.0
# 7741     -118.15     33.95                35.0       2753.0      1592.0
# 4425     -118.24     34.07                27.0        223.0       249.0
# 1283     -121.82     38.02                46.0        176.0       101.0
# ...          ...       ...                 ...          ...         ...
# 1221     -120.65     38.28                21.0       3095.0      1341.0
# 12640    -121.45     38.53                34.0       1893.0       884.0
# 5747     -118.27     34.17                48.0       1560.0       825.0
# 16224    -121.33     37.98                36.0       3113.0      1746.0
# 8967     -118.40     34.00                37.0       1534.0       751.0
#
#        households  median_income ocean_proximity  identifier  rooms_per_house  \
# ...

# %%
#the last solution: place median or average values in null.
#train features with imputed na values:
total_bedrooms_median=train_features["total_bedrooms"].median()
train_features["total_bedrooms"]=train_features["total_bedrooms"].fillna(total_bedrooms_median)

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16512 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   ocean_proximity     16512 non-null  object
#  9   identifier          16512 non-null  float64
#  10  rooms_per_house     16512 non-null  float64
#  11  bedrooms_ratio      16344 non-null  float64
#  12  people_per_house    16512 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.8+ MB

# %%
train_features["bedrooms_ratio"]=train_features["total_bedrooms"]/train["total_rooms"]
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16512 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   ocean_proximity     16512 non-null  object
#  9   identifier          16512 non-null  float64
#  10  rooms_per_house     16512 non-null  float64
#  11  bedrooms_ratio      16512 non-null  float64
#  12  people_per_house    16512 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.8+ MB

# %%
#You can do it with sikit learn: Sklearn impute
from sklearn.impute import SimpleImputer
simple_imputer= SimpleImputer(strategy='median')
train_features=train.drop("median_house_value", axis=1)
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16344 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   ocean_proximity     16512 non-null  object
#  9   identifier          16512 non-null  float64
#  10  rooms_per_house     16512 non-null  float64
#  11  bedrooms_ratio      16344 non-null  float64
#  12  people_per_house    16512 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 1.8+ MB

# %%
#we have 'object' type values which median can not execute on.
#so, we save only numeric columns.
train_features_numeric=train_features.select_dtypes(include=[np.number])
train_features_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16344 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   identifier          16512 non-null  float64
#  9   rooms_per_house     16512 non-null  float64
#  10  bedrooms_ratio      16344 non-null  float64
#  11  people_per_house    16512 non-null  float64
# dtypes: float64(12)
# memory usage: 1.6 MB

# %%
#it finds the median of columns.
simple_imputer.fit(train_features_numeric)
# Out:
# SimpleImputer(strategy='median')

# %%
simple_imputer.statistics_#they are median of our 12 columns.
# Out:
# array([-1.18480000e+02,  3.42500000e+01,  2.90000000e+01,  2.12900000e+03,
#         4.36000000e+02,  1.16800000e+03,  4.11000000e+02,  3.53410000e+00,
#        -1.18445990e+05,  5.22483203e+00,  2.03423233e-01,  2.82065903e+00])

# %%
simple_imputer.transform(train_features_numeric)
# Out:
# (16512, 12)

# %%
pd.DataFrame(simple_imputer.transform(train_features_numeric),columns=train_features_numeric.columns,index=train_features_numeric.index)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16415    -121.26     37.88                42.0        465.0            93.0
# 1279     -121.64     37.85                22.0       1999.0           415.0
# 7741     -118.15     33.95                35.0       2753.0           702.0
# 4425     -118.24     34.07                27.0        223.0            80.0
# 1283     -121.82     38.02                46.0        176.0            43.0
# ...          ...       ...                 ...          ...             ...
# 1221     -120.65     38.28                21.0       3095.0           681.0
# 12640    -121.45     38.53                34.0       1893.0           415.0
# 5747     -118.27     34.17                48.0       1560.0           280.0
# 16224    -121.33     37.98                36.0       3113.0           576.0
# 8967     -118.40     34.00                37.0       1534.0           258.0
#
# ...

# %%
pd.DataFrame(simple_imputer.transform(train_features_numeric),columns=train_features_numeric.columns,index=train_features_numeric.index).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16512 entries, 16415 to 8967
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  float64
#  3   total_rooms         16512 non-null  float64
#  4   total_bedrooms      16512 non-null  float64
#  5   population          16512 non-null  float64
#  6   households          16512 non-null  float64
#  7   median_income       16512 non-null  float64
#  8   identifier          16512 non-null  float64
#  9   rooms_per_house     16512 non-null  float64
#  10  bedrooms_ratio      16512 non-null  float64
#  11  people_per_house    16512 non-null  float64
# dtypes: float64(12)
# memory usage: 1.6 MB

# %%
#In addition to simple_imputer, we have other ready functions in sklearn(search it)
